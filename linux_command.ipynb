# %% [markdown]
# <a href="https://colab.research.google.com/github/bctcaiedu/linux/blob/main/linux_command.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # ls 명령어 설명
# ls (list segments) 명령어는 리눅스/유닉스 환경에서 디렉토리 내부의 파일과 하위 디렉토리 목록을 화면에 출력하는 핵심 명령어입니다. 기본적으로 현재 디렉토리의 내용을 보여주며, 다양한 옵션을 통해 상세 정보, 숨김 파일, 정렬 방식 등을 제어할 수 있습니다.
# # 주요 ls 명령어 옵션
#
# *   ls -l: 상세 정보(권한, 소유자, 크기, 수정 시간)를 롱 포맷으로 표시.
# *   ls -a: 숨김 파일(.)을 포함한 모든 파일 표시.

# %%
# !cd
# Out:
# bin	 datalab  home	  lib32   media  proc		    root  srv  tools
# boot	 dev	  kaggle  lib64   mnt	 python-apt	    run   sys  usr
# content  etc	  lib	  libx32  opt	 python-apt.tar.xz  sbin  tmp  var

# %%
# !pwd
# Out:
# /content

# %%
# !whoami
# Out:
# root

# %%
# !mkdir test

# %%
# !uname -a
# Out:
# Linux a5f855800200 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux

# %%
# !chmod

# %% [markdown]
# # chmod 명령어
# 리눅스/유닉스에서 파일이나 디렉터리의 권한을 변경하는 명령어
#
# chmod [옵션] 권한 파일명
#
#
#
#
# *  r (read) = 읽기 (4)
# *  w (write) = 쓰기 (2)
# *  x (execute) = 실행 (1)
#
# 그리고 적용 대상은 3가지입니다:
#
# * u (user) = 소유자
# * g (group) = 그룹
# * o (others) = 그 외 사용자

# %%
# !chown

# %%
# !ln
